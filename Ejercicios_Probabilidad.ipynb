# %% [markdown]
# # ***PROBABILIDAD Y ESTADISTICA EN PYTHON***

# %%
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd # importando pandas

np.random.seed(2131982) # para poder replicar el random

# %%
datos = np.random.randn(5, 4) # datos normalmente distribuidos
datos
# Out:
# array([[ 0.46038022, -1.08942528, -0.62681496, -0.63329028],
#        [-0.1074033 , -0.88138082, -0.34466623, -0.28320214],
#        [ 0.94051171,  0.86693793,  1.20947882, -0.16894118],
#        [-0.12790177, -0.58099931, -0.46188426, -0.18148302],
#        [-0.76959435, -1.37414587,  1.37696874, -0.18040537]])

# %% [markdown]
# **Pregunta 1**
# Una máquina automática llena bolsas de plástico con una combinación de
# frijoles, brócoli y otras verduras. La mayoría de las bolsas contienen el peso
# correcto, aunque como consecuencia de la variación del tamaño del frijol y de
# otras verduras, un paquete podría pesar menos o más. Una revisión de 4000
# paquetes que se llenaron el mes pasado arrojo los siguientes datos.

# %%
# usando pandas
dataframe = pd.DataFrame(datos, index=['Menos peso', 'Peso satisfactorio', 'Mas peso', 'Total'], 
                        columns=['Peso', 'Evento', 'Numero de paquetes'])
dataframe

# %%
#¿Cuál es la probabilidad de que el paquete pese menos o mas?
#P(A)=100 ----Pesa menos
#P(A)=3600 ---Pesa bien 
#P(A)=300 ----Pesa mas 
probaba=100/4000
probaba=0.025
probabib=3600/4000
probabib=0.900
probabilc=300/4000
probabilc=0.075
probabilidad_menos_o_mas = (0.025 + 0.075)
probabilidad_menos_o_mas*100
# Out:
# 10.0

# %%
#¿Cuál es la probabilidad de que un paquete pese satisfactoriamente o pese mas?
A=0.025 
B=.900
C=0.075
#PA=1-PA=PC+PB
Promsatmas=1-0.025
Promsatmas*100
# Out:
# 97.5

# %%
#¿Cuál es la probabilidad de que un pauete pese satisfactoriamnet?
probabilidad_satis=0.025+0.075 
probabilidad_satis=(1-0.1)*100
probabilidad_satis
# Out:
# 90.0

# %% [markdown]
# ### Pregunta 2
# Una encuesta de 34 estudiantes en la Wall College of Business mostro que estos
# tienen las siguientes especialidades:
# Especialidad    Estudiantes
# Contabilidad      10
# Finanzas           5
# Economía           3
# Administración     6
# Marketing         10

# %%
#¿Cuál es la probabilidad de que un estudiante tenga la especialidad de Administración?
PA=6/34 *100
PA
# Out:
# 17.647058823529413

# %%
#¿Cuál es la probabilidad de que el estudiante tenga una ezpecialidad en finanzas?
PF=5/34 * 100
PF
# Out:
# 14.705882352941178

# %%
#¿Cuál es la probabilidad de que el estudiante estudie una especialidad de contabilidad?
PC=10/34 *100
PC
# Out:
# 29.411764705882355

# %% [markdown]
# **Pregunta 3**
# Se hace una quiniela con un dado para hacer quinielas que lleva en sus caras tres
# veces el 1, dos veces la X y una vez el 2. Calcula la probabilidad de que salga una
# X o un 2.

# %%
#2 casos favorables en X
#6 casos posibles en X
ProbcasosX=2/6* 100
ProbcasosX
# Out:
# 33.33333333333333

# %%
#1 caso favorable en 2
#6 casos posibles en 2
Probcasos2= 1/6*100
Probcasos2
# Out:
# 16.666666666666664

# %% [markdown]
# **Medidas de Dispersión**
#
# Pregunta 1
# Dados los pesos de 10 niños: 42 kg, 38 kg, 46 kg, 40 kg, 43 kg, 48 kg, 45 kg,
# 43 kg, 41 kg y 39 kg. ¿Cuál(es) de las afirmaciones siguientes es (son)
# verdadera(s)?
# I) La moda de la distribución es 43 kg.
# II) El promedio es menor que 43 kg.
# III) La mediana coincide con la moda

# %%
#Mediana
datos = [42,38,46,40,43,48,45,43,41,39]
np.median(datos)
# Out:
# 42.5

# %%
#Promedio
datos = [42,38,46,40,43,48,45,43,41,39]
np.mean(datos)
# Out:
# 42.5

# %%
#Moda
datos = [42,38,46,40,43,48,45,43,41,39]
stats.mode(datos)
# Out:
# ModeResult(mode=array([43]), count=array([2]))

# %% [markdown]
# **Pregunta 2**
# La tabla adjunta muestra las edades de 220 alumnos de un colegio ¿Cuál(es)
# de las siguientes afirmaciones es (son) verdadera(s)?
#
# I) La moda es 17 años.
# II) La mediana es mayor que la media (promedio).
# III) La mitad de los alumnos del colegio tiene 17 o 18 años

# %%
#Moda 
#  Edad (en años)   alumnos
#  15                50
#  16                40
#  17                60
#  18                50
#  19                20
#             Total 220

datos = [15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,19,19,19,19,19,19,19,19,19,19]
stats.mode(datos)
# Out:
# ModeResult(mode=array([17]), count=array([60]))

# %%
#Mediana 
datos = [15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,19,19,19,19,19,19,19,19,19,19]
np.mean(datos)
# Out:
# 16.666666666666668

# %%
#La mayoria de los alumnos de la escuela tiene entre 17 y 18 años
#EL TOTAL SON 220
T=220/2
T
Diecisiete=60
Dieciocho=50
X= Diecisiete+Dieciocho
X
#Si nos fijamos en la tabla nos daremos cuenta que la suma del total de alumnos de 17 y 18 son 110, por lo que esta opcion es verdadera
# Out:
# 110

# %% [markdown]
# **Pregunta 3**
# La división de servicios alimentarios de Ceda River Amusement Park, Inc.,
# estudia la cantidad que gasta al día en alimentos y bebida las familias que visitan
# el parque de diversiones. Una muestra de 40 familias que visito el parque ayer
# revela que estas gastan las siguientes cantidades:
#
# a) Organiza los datos en una tabla de frecuencias.
# b) Obtén las medidas de tendencia central para este caso.

# %% [markdown]
# ![20210209_201031_HDR~2.jpg](data:image/jpeg;base64,...)

# %%
#Mediana de Datos 
datos = [18,26,34,36,38,41,43,44,45,50,50,51,52,52,53,53,54,54,56,58,58,58,59,60,60,61,61,62,62,62,63,63,63,65,66,71,71,77,83,84]
np.median(datos)
# Out:
# 58.0

# %%
#Media
datos = [18,26,34,36,38,41,43,44,45,50,50,51,52,52,53,53,54,54,56,58,58,58,59,60,60,61,61,62,62,62,63,63,63,65,66,71,71,77,83,84]
np.mean(datos)
# Out:
# 55.425

# %%
#Moda 
datos = [18,26,34,36,38,41,43,44,45,50,50,51,52,52,53,53,54,54,56,58,58,58,59,60,60,61,61,62,62,62,63,63,63,65,66,71,71,77,83,84]
stats.mode(datos)
# Out:
# ModeResult(mode=array([58]), count=array([3]))

# %% [markdown]
# **Medidas de Tendencia Central**
# Pregunta 1
# Dados los pesos de 10 niños: 42 kg, 38 kg, 46 kg, 40 kg, 43 kg, 48 kg, 45 kg, 43 kg, 41 kg y 39
# kg. ¿Cuál(es) de las afirmaciones siguientes es (son) verdadera(s)?
# I) La desviación estándar es 3.17 kg.
# II) la varianza es menor que 9 kg.
# III) La desviación coincide con la varianza.

# %%
#La desviación estándar es 3.17 kg.

datos = [42,38,46,40,43,48,45,43,41,39]
np.std(datos)
# Out:
# 3.0083217912982647

# %%
# la varianza es menor que 9 kg.
datos = [42,38,46,40,43,48,45,43,41,39]
np.cov(datos)
# Out:
# array(10.05555556)

# %%
#La desviación coincide con la varianza
import math
math.sqrt(10.05555556)   #sacamos raíz de la varianza para comprobar
# Out:
# 3.171049599107526

# %% [markdown]
# **Pregunta 2**
# Con la tabla de frecuencias que se obtuvo en la pregunta 3 de la actividad 1.2 medidas de
# tendencia central obtenga la varianza y desviación estándar muestral para este caso.

# %%
#Varianza de la pregunta 3 de la actividad 1.2 medidas de tendencia central
datos = [18,26,34,36,38,41,43,44,45,50,50,51,52,52,53,53,54,54,56,58,58,58,59,60,60,61,61,62,62,62,63,63,63,65,66,71,71,77,83,84]
np.cov(datos)
# Out:
# array(187.07115385)

# %%
#Desviacion de la pregunta 3 de la actividad 1.2 medidas de tendencia central
import numpy as np
from scipy import stats
import pandas as pd
datos = [18,26,34,36,38,41,43,44,45,50,50,51,52,52,53,53,54,54,56,58,58,58,59,60,60,61,61,62,62,62,63,63,63,65,66,71,71,77,83,84]
np.std(datos)
# Out:
# 13.505346163649417

# %% [markdown]
# ***Pregunta 3***
# Una muestra de 10 estudiantes universitarios reporto las siguientes cifras en dólares de gastos
# por concepto de entretenimiento el año pasado

# %%
#Desviación 
datos = [684,763,710,681,688,731,722,771,698,711]
np.std(datos)
# Out:
# 29.85448040077067

# %%
#Varianza
datos = [684,763,710,681,688,731,722,771,698,711]
np.cov(datos)
# Out:
# array(990.32222222)

# %% [markdown]
# Creo que unas cosas son diferentes al documento, necesito checar bien las formulas de mi pdf, al igual  que ver videos para que me quede mas claro, YA QUE EN DONDE ME EQUIVOQUE ES EN VARIANZA Y DESVIASIÓ, SOLAMENTE EN 2 PREGUNTAS
